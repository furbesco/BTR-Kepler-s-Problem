# %% [markdown]
# ## Post Processing for the main code

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Import the CSV file

# %%
df = pd.read_csv('1PN_output.csv')

t = df["t"].to_numpy()
E = df["l"].to_numpy() 
u = df["u"].to_numpy() 
R = df["R"].to_numpy()
v = df["v"].to_numpy() 
phi = df["phi"].to_numpy() 
x = df["x"].to_numpy()
y = df["y"].to_numpy()

# %%
plt.figure() 
plt.plot(x, y, label="Orbit", color = "hotpink")
plt.scatter([0], [0], s=20, label="Centre Mass", color = "dodgerblue") 
plt.gca().set_aspect("equal", adjustable="box")
plt.xlabel("x") 
plt.ylabel("y")
plt.title("1PN Orbit")
plt.legend() 
plt.tight_layout()
plt.show()

# %%
plt.plot(M, phi)
plt.xlabel("M")
plt.ylabel("phi")
plt.title("True anomaly vs mean anomaly")
plt.show()

# %% [markdown]
# The periodicity is from the orbit completing revolutions from -pi to pi.

# %%
# sort so curve looks nice, one orbit from 0 to 2 pi
M_mod = np.mod(M, 2*np.pi) 
idx = np.argsort(M_mod)  

plt.figure()
plt.plot(M_mod[idx], r[idx])
plt.xlabel("M, 2π"); plt.ylabel("r")
plt.title("Radius r vs mean anomaly ")
plt.show()
